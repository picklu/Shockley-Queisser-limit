# %%
from SQlimit import SQlim

# %%
SQ = SQlim()
SQ.plot()
SQ.plotall()
SQ.E_loss(1.337)
SQ.available_E(1.6)

# %%
from spectra import plot_spectra

# %%
plot_spectra(SQ.WLs, SQ.AM15nm, xlim=(380,800))
